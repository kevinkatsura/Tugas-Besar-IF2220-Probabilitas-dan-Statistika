# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

df = pd.read_csv('Gandum.csv', header = None)

df.columns = ["Id", "Daerah", "SumbuUtama", "SumbuKecil", "Keunikan", "AreaBulatan", "Diameter", "KadarAir", "Keliling", "Bulatan", "Ransum", "Kelas"]

df = df.drop(["Id","Kelas"], axis=1)

# %% [markdown]
# ## **Nomor 3**
#     Menentukan setiap kolom numerik berdistribusi normal atau tidak. Gunakan normality test
#     yang dikaitkan dengan histogram plot.

# %% [markdown]
# ### **Kolom Daerah**

# %%
# Menggunakan Histogram
# Histogram Kolom Daerah
sns.set_theme()
sns.histplot(data=df["Daerah"],kde=True)
plt.show()

# %% [markdown]
# Data di atas **terdistribusi normal** karena  kurva nya **simetris**

# %%
# Menggunakan scipy
x = np.random.normal(df["Daerah"])
p = stats.normaltest(x)
alpha = 1e-3
print("p = {:g}".format(p))
if p < alpha:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis can be rejected")
else:
    print("The null hypothesis cannot be rejected")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-28066e26f9db> in <module>
#       2 p = stats.normaltest(df["Daerah"])
#       3 alpha = 1e-3
# ----> 4 print("p = {:g}".format(p))
#       5 if p < alpha:  # null hypothesis: x comes from a normal distribution
#       6     print("The null hypothesis can be rejected")
#
# TypeError: unsupported format string passed to NormaltestResult.__format__

# %% [markdown]
# ### **Kolom SumbuUtama**

# %%
# Histogram Kolom SumbuUtama
sns.set_theme()
sns.histplot(data=df["SumbuUtama"],kde=True)
plt.show()

# %% [markdown]
# Data di atas **moderately terdistribusi normal** karena  kurva nya **cukup simetris**

# %% [markdown]
# ### **Kolom SumbuKecil**

# %%
# Histogram Kolom SumbuKecil
sns.set_theme()
sns.histplot(data=df["SumbuKecil"],kde=True)
plt.show()

# %% [markdown]
# Data di atas **terdistribusi normal** karena  kurva nya **tepat simetris**

# %% [markdown]
# ### **Kolom Keunikan**

# %%
# Histogram Kolom SumbuKecil
sns.set_theme()
sns.histplot(data=df["Keunikan"],kde=True)
plt.show()

# %% [markdown]
# Data di atas **tidak terdistribusi normal** karena  kurva nya **tidak simetris**

# %% [markdown]
# ### **Kolom AreaBulatan**

# %%
# Histogram Kolom SumbuKecil
sns.set_theme()
sns.histplot(data=df["AreaBulatan"],kde=True)
plt.show()

# %% [markdown]
# Data di atas **terdistribusi normal** karena  kurva nya **simetris**

# %% [markdown]
# ### **Kolom Diameter**

# %%
# Histogram Kolom SumbuKecil
sns.set_theme()
sns.histplot(data=df["Diameter"],kde=True)
plt.show()

# %% [markdown]
# Data di atas **terdistribusi normal** karena  kurva nya **simetris**

# %% [markdown]
# ### **Kolom KadarAir**

# %%
# Histogram Kolom SumbuKecil
sns.set_theme()
sns.histplot(data=df["KadarAir"],kde=True)
plt.show()

# %% [markdown]
# Data di atas masih **terdistribusi normal** karena  kurva nya **cukup simetris**

# %% [markdown]
# ### **Kolom Keliling**

# %%
# Histogram Kolom SumbuKecil
sns.set_theme()
sns.histplot(data=df["Keliling"],kde=True)
plt.show()

# %% [markdown]
# Data di atas **moderately terdistribusi normal** karena  kurva nya **cukup simetris**

# %% [markdown]
# ### **Kolom Bulatan**

# %%
# Histogram Kolom SumbuKecil
sns.set_theme()
sns.histplot(data=df["Bulatan"],kde=True)
plt.show()

# %% [markdown]
# Data di atas **tidak terdistribusi normal** karena  kurva nya **sangat tidak simetris**. Nilai nilai pencilan yang ada berpengaruh besar pada kesimetrisan diagram di atas.

# %% [markdown]
# ### **Kolom Ransum**

# %%
# Histogram Kolom SumbuKecil
sns.set_theme()
sns.histplot(data=df["Ransum"],kde=True)
plt.show()

# %% [markdown]
# Data di atas **terdistribusi normal** karena  kurva nya **cukup simetris**
